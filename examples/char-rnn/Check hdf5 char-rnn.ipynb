# %%
import h5py
import numpy as np
f = h5py.File('shakespeare.h5', 'r')
for k in f.keys():
    print k
# Out:
# cont
# input
# target

# %%
inp = f['cont']
inp.shape
# Out:
# (8950, 100)

# %%
vocabulary = ['<EOS>'] + [line.strip() for line in
                          open('vocabulary.txt').readlines()]
vocabulary[-1] = ''
print len(vocabulary)
# Out:
# 66

# %%
stream_1 = inp[:, 0].astype(int)
sentences = np.split(stream_1, len(stream_1) / 50)
for i in xrange(0,100):
    print [vocabulary[index] for index in sentences[i]], '\n'
# Out:
# ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
#
# ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
#
# ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
#
# ...
